# %% [markdown]
# # SoMe content
#
# ## Sustainable finance trend radar
# #### 1. Topics that appeared
# #### 2. Topics that dropped out
# #### 3. Ranks and rank changes

# %% [markdown]
# ## Extract

# %%
# %%writefile ../pipelines/analysis_dashboard/extract.py
"""
~-- EXTRACT
Loads the queried data from the raw data directory
"""

from glob import glob
import os
import pandas as pd

def load_data(raw_data_dir, filename):
    # merge all data from directory
    data_files = glob(f'{os.path.join(raw_data_dir, filename)}*')
    df_list = [pd.read_csv(file) for file in data_files]
    df = pd.concat(df_list).reset_index(drop=True)
    
    return df
# Out:
# Overwriting ../pipelines/analysis_dashboard/extract.py

# %%
# %%writefile ../pipelines/analysis_dashboard/transform.py
"""
~-- TRANSFORM
Create relevant statistics about Google trends data
"""

import pandas as pd

def trends_statistics(df, rank_category='rising'):
    """Generate relevant statistics for a ranking category of Google trends (rising or top)"""
    
    ## subset by Google Trends category: rising or top
    df = df.loc[df.ranking == rank_category].reset_index(drop=True) # select only rising topics

    ## datetime
    # timestamp to date
    df['query_date'] = pd.to_datetime(df.query_timestamp).dt.date
    # time series indicator: t
    df['t'] = df.groupby('query_date').ngroup() 
    # most recent period
    t_max = df.t.max() # most recent

    ## ranking 
    # absolute
    df['rank_t'] = df.groupby('t').value.rank(method='first', ascending=False) 
    df['rank_t-1'] = df.groupby('query').rank_t.shift() # rank in previous period (t-1) 
    df['rank_absolute_change'] = df.rank_t - df['rank_t-1'] # rank change from previous, t-1, to current period, t
    # winners and loosers (ranking of absoulte changes)
    df['rank_absoulte_change_ranking'] =  df.groupby('t').rank_absolute_change.rank(method='first', ascending=False)
    
    # percentile
    df['rank_pct_t'] = df.groupby('t').value.rank(method='first', ascending=False, pct=True)
    df['rank_pct_t-1'] = df.groupby('query').rank_pct_t.shift()
    df['rank_pct_change'] = df.rank_pct_t - df['rank_pct_t-1']    

    ## new entries at time t
    df['new_entry_t'] = (pd.isna(df['rank_t-1']) & pd.notnull(df.rank_t))*1
    
    ## dropouts at time t+1
    # keywords for each period  to compare sets
    queries_dict = df.groupby('t')['query'].apply(list).to_dict()
    # compare query responses sets across last two periods 
    dropouts = list(set(queries_dict[t_max-1]).difference(set(queries_dict[t_max]))) 
    df['dropout_t+1'] = ((df.t == t_max-1) & df['query'].isin(dropouts))*1

    ## fill missings
    df = df.fillna(0)
    
    return df

def dashboard_data(df):
    """Create statistics for each category and concatenate dataframes """
    ranking_categories = df.ranking.unique().tolist()
    df = pd.concat([trends_statistics(df, rank_category=r) for r in ranking_categories])
    
    return df
# Out:
# Overwriting ../pipelines/analysis_dashboard/transform.py

# %% [markdown]
# ## Development / Testing

# %%
from glob import glob
glob('../data/2_final/*')
# Out:
# ['../data/2_final\\esg_trends_analysis.csv',
#  '../data/2_final\\esg_trends_analysis_210405_1327.csv',
#  '../data/2_final\\README.md',
#  '../data/2_final\\sustainable_finance.csv']

# %%
# %load ../serve/utils/app_utilities.py
import yaml
import os
import pandas as pd

def load_config(filepath):
	"""Return dictionary with settings"""
	with open(filepath) as file:
		config = yaml.full_load(file)
		return config

def load_data(filepath):
	"""Read csv-only file from data_dir/filename"""
	df = pd.read_csv(filepath)
	return df

# %%
df = load_data('../data/2_final/esg_trends_analysis.csv').query("ranking == 'rising'")
df.query_date = pd.to_datetime(df.query_date).dt.strftime('%d.%m.%Y')

# -- process data
t_most_recent = df.t.max()-1
# most recent date
date_most_recent = df.loc[df.t==t_most_recent].query_date.unique()[0]

df_selected_date = df.loc[df.query_date==date_most_recent].drop_duplicates(subset=['ranking', 'query', 'query_date'])

df_selected_date.sort_values(by='rank_t').loc[:,['query', 'rank_t', 'rank_absolute_change', 'query_date']].head(10)
# Out:
#                                               query  rank_t  \
# 3705                sustainable finance action plan     1.0
# 3706                                       taxonomy     2.0
# 3707                eu sustainable finance taxonomy     3.0
# 3708             eu sustainable finance action plan     4.0
# 3691                                           sdgs    17.0
# 3692                                       sdgs esg    19.0
# 3709      sustainable finance disclosure regulation    23.0
# 3710          eu action plan on sustainable finance    24.0
# 3711  international platform on sustainable finance    31.0
# 3726       socially responsible investment advisors    32.0
#
#       rank_absolute_change  query_date
# 3705                 -33.0  05.04.2021
# 3706                   0.0  05.04.2021
# 3707                  -2.0  05.04.2021
# 3708                   0.0  05.04.2021
# 3691                  12.0  05.04.2021
# 3692                  15.0  05.04.2021
# 3709                  14.0  05.04.2021
# 3710                   3.0  05.04.2021
# 3711                  12.0  05.04.2021
# 3726                  16.0  05.04.2021

# %%
# Out:
#                                           query  value  \
# 3681          best sustainable investment funds  49800
# 3682  global sustainable investment review 2018  16600
# 3683              sustainable development goals    850
# 3684       global sustainable investment review    500
# 3685     global sustainable investment alliance    400
# ...                                         ...    ...
# 3783                     sustainable finance eu   2850
# 3788                sustainable capital finance     40
# 3857  pri principles for responsible investment    140
# 3859                                        pri    130
# 3861             what is responsible investment    120
#
#                      keyword ranking     geo             query_timestamp  \
# 3681  sustainable investment  rising  global  2021-04-05 13:36:31.561587
# 3682  sustainable investment  rising  global  2021-04-05 13:36:31.561587
# 3683  sustainable investment  rising  global  2021-04-05 13:36:31.561587
# 3684  sustainable investment  rising  global  2021-04-05 13:36:31.561587
# 3685  sustainable investment  rising  global  2021-04-05 13:36:31.561587
# ...                      ...     ...     ...                         ...
# 3783     sustainable finance  rising  global  2021-04-05 13:37:09.030702
# 3788     sustainable finance  rising  global  2021-04-05 13:37:09.030702
# 3857  responsible investment  rising  global  2021-04-05 13:38:23.892142
# 3859  responsible investment  rising  global  2021-04-05 13:38:23.892142
# 3861  responsible investment  rising  global  2021-04-05 13:38:23.892142
#
#       query_date   t  rank_t  rank_t-1  rank_absolute_change  \
# 3681  05.04.2021  23    49.0      29.0                  20.0
# 3682  05.04.2021  23    96.0      50.0                  46.0
# 3683  05.04.2021  23   140.0      35.0                 105.0
# 3684  05.04.2021  23   148.0      39.0                 109.0
# 3685  05.04.2021  23   149.0      38.0                 111.0
# ...          ...  ..     ...       ...                   ...
# 3783  05.04.2021  23   130.0      31.0                  99.0
# 3788  05.04.2021  23   240.0      42.0                 198.0
# 3857  05.04.2021  23   181.0      50.0                 131.0
# 3859  05.04.2021  23   185.0      46.0                 139.0
# 3861  05.04.2021  23   191.0      48.0                 143.0
#
#       rank_absoulte_change_ranking  rank_pct_t  rank_pct_t-1  rank_pct_change  \
# 3681                          83.0    0.200820      0.547170        -0.346350
# 3682                          68.0    0.393443      0.757576        -0.364133
# 3683                          32.0    0.573770      0.660377        -0.086607
# 3684                          29.0    0.606557      0.735849        -0.129292
# 3685                          27.0    0.610656      0.716981        -0.106325
# ...                            ...         ...           ...              ...
# 3783                          37.0    0.532787      0.584906        -0.052119
# 3788                           1.0    0.983607      0.736842         0.246764
# 3857                          23.0    0.741803      0.877193        -0.135390
# 3859                          18.0    0.758197      0.807018        -0.048821
# 3861                          16.0    0.782787      0.905660        -0.122873
#
#       new_entry_t  dropout_t+1
# 3681            0            1
# 3682            0            1
# 3683            0            1
# 3684            0            0
# 3685            0            0
# ...           ...          ...
# 3783            0            1
# 3788            0            1
# 3857            0            1
# 3859            0            0
# 3861            0            1
#
# [82 rows x 17 columns]

# %%
df_selected_date.sort_values(by='rank_absolute_change').loc[:,['query', 'rank_t', 'rank_absolute_change']].head(10)
# Out:
#                                                query  rank_t  \
# 3243          environmentally responsible investment     8.0
# 3230                     sustainable finance courses    14.0
# 3220             axis esg equity fund regular growth    31.0
# 3231  high-level expert group on sustainable finance    15.0
# 3201          global sustainable investment alliance    38.0
# 3203                     sustainable investment fund    44.0
# 3240                       swiss sustainable finance    37.0
# 3214                                  esg stands for    24.0
# 3207               sustainable investment management    50.0
# 3215                    kotak esg opportunities fund    25.0
#
#       rank_absolute_change
# 3243                 -35.0
# 3230                 -27.0
# 3220                 -26.0
# 3231                 -18.0
# 3201                  -7.0
# 3203                  -7.0
# 3240                  -6.0
# 3214                  -6.0
# 3207                  -5.0
# 3215                  -5.0

# %% [markdown]
# ## Analyses
# ### Newcomer

# %%
df_selected_date.loc[(df_selected_date.t == t_most_recent) & (df_selected_date.new_entry_t == 1)]
# Out:
#                                    query  value keyword ranking     geo  \
# 3219  axis esg equity fund direct growth   5350     ESG  rising  global
#
#                  query_timestamp  query_date   t  rank_t  rank_t-1  \
# 3219  2021-04-02 08:31:37.360007  02.04.2021  22    30.0       0.0
#
#       rank_absolute_change  rank_absoulte_change_ranking  rank_pct_t  \
# 3219                   0.0                           0.0    0.566038
#
#       rank_pct_t-1  rank_pct_change  new_entry_t  dropout_t+1
# 3219           0.0              0.0            1            0

# %% [markdown]
# ### Dropouts

# %%
df.loc[(df.t == t_max-1) & (df['dropout_t+1'] == 1)]
# Out:
#                                               query   value  \
# 1258  journal of sustainable finance and investment     120
# 1260                                            sri      60
# 1263                                   vanguard esg   47950
# 1265                                 icici esg fund   24150
# 1266                     sbi magnum equity esg fund   22100
# 1267                               msci esg ratings   19400
# 1268                       axis esg equity fund nav   14400
# 1269                            esg investing funds   12500
# 1270                          esg investing meaning   12050
# 1271                        esg investing companies    9500
# 1273                             what are esg funds    7000
# 1277                   taxonomy sustainable finance  209950
# 1278             eu sustainable finance action plan  152650
# 1279                eu sustainable finance taxonomy  113150
# 1282                                           sfdr   52600
# 1290                   sustainable finance platform     300
# 1292                    sustainable capital finance     250
# 1293        sustainable finance european commission     150
# 1294                      sustainable finance forum      50
# 1301                                            pri     160
# 1302                                            esg     160
# 1305      socially responsible investment companies     110
# 1306      socially responsible investment portfolio      70
# 1307              responsible investment strategies      60
#
#                      keyword ranking     geo             query_timestamp  \
# 1258  sustainable investment  rising  global  2021-04-01 06:40:13.022014
# 1260  sustainable investment  rising  global  2021-04-01 06:40:13.022014
# 1263                     ESG  rising  global  2021-04-01 06:40:13.022014
# 1265                     ESG  rising  global  2021-04-01 06:40:13.022014
# 1266                     ESG  rising  global  2021-04-01 06:40:13.022014
# 1267                     ESG  rising  global  2021-04-01 06:40:13.022014
# 1268                     ESG  rising  global  2021-04-01 06:40:13.022014
# 1269                     ESG  rising  global  2021-04-01 06:40:13.022014
# 1270                     ESG  rising  global  2021-04-01 06:40:13.022014
# 1271                     ESG  rising  global  2021-04-01 06:40:13.022014
# 1273                     ESG  rising  global  2021-04-01 06:40:13.022014
# 1277     sustainable finance  rising  global  2021-04-01 06:40:13.022014
# 1278     sustainable finance  rising  global  2021-04-01 06:40:13.022014
# 1279     sustainable finance  rising  global  2021-04-01 06:40:13.022014
# 1282     sustainable finance  rising  global  2021-04-01 06:40:13.022014
# 1290     sustainable finance  rising  global  2021-04-01 06:40:13.022014
# 1292     sustainable finance  rising  global  2021-04-01 06:40:13.022014
# 1293     sustainable finance  rising  global  2021-04-01 06:40:13.022014
# 1294     sustainable finance  rising  global  2021-04-01 06:40:13.022014
# 1301  responsible investment  rising  global  2021-04-01 06:40:13.022014
# 1302  responsible investment  rising  global  2021-04-01 06:40:13.022014
# 1305  responsible investment  rising  global  2021-04-01 06:40:13.022014
# 1306  responsible investment  rising  global  2021-04-01 06:40:13.022014
# 1307  responsible investment  rising  global  2021-04-01 06:40:13.022014
#
#       query_date  day  month  year   t  rank_t  rank_t-1  rank_change  \
# 1258  2021-04-01    1      4  2021  21    50.0      42.0          8.0
# 1260  2021-04-01    1      4  2021  21    55.0      48.0          7.0
# 1263  2021-04-01    1      4  2021  21    11.0      18.0         -7.0
# 1265  2021-04-01    1      4  2021  21    19.0      19.0          0.0
# 1266  2021-04-01    1      4  2021  21    21.0      26.0         -5.0
# 1267  2021-04-01    1      4  2021  21    23.0       NaN          NaN
# 1268  2021-04-01    1      4  2021  21    24.0      30.0         -6.0
# 1269  2021-04-01    1      4  2021  21    25.0       NaN          NaN
# 1270  2021-04-01    1      4  2021  21    26.0      29.0         -3.0
# 1271  2021-04-01    1      4  2021  21    27.0      33.0         -6.0
# 1273  2021-04-01    1      4  2021  21    29.0      28.0          1.0
# 1277  2021-04-01    1      4  2021  21     3.0       2.0          1.0
# 1278  2021-04-01    1      4  2021  21     4.0       4.0          0.0
# 1279  2021-04-01    1      4  2021  21     5.0       5.0          0.0
# 1282  2021-04-01    1      4  2021  21    10.0      23.0        -13.0
# 1290  2021-04-01    1      4  2021  21    39.0      36.0          3.0
# 1292  2021-04-01    1      4  2021  21    42.0      42.0          0.0
# 1293  2021-04-01    1      4  2021  21    48.0       7.0         41.0
# 1294  2021-04-01    1      4  2021  21    57.0      49.0          8.0
# 1301  2021-04-01    1      4  2021  21    46.0      53.0         -7.0
# 1302  2021-04-01    1      4  2021  21    47.0      46.0          1.0
# 1305  2021-04-01    1      4  2021  21    52.0      52.0          0.0
# 1306  2021-04-01    1      4  2021  21    54.0      49.0          5.0
# 1307  2021-04-01    1      4  2021  21    56.0      44.0         12.0
#
#       rank_pct_t  rank_pct_t-1  rank_pct_change  new_entry_t  dropout_t+1
# 1258    0.877193      0.736842         0.140351            0            1
# 1260    0.964912      0.905660         0.059252            0            1
# 1263    0.192982      0.321429        -0.128446            0            1
# 1265    0.333333      0.358491        -0.025157            0            1
# 1266    0.368421      0.490566        -0.122145            0            1
# 1267    0.403509           NaN              NaN            1            1
# 1268    0.421053      0.566038        -0.144985            0            1
# 1269    0.438596           NaN              NaN            1            1
# 1270    0.456140      0.547170        -0.091029            0            1
# 1271    0.473684      0.589286        -0.115602            0            1
# 1273    0.508772      0.474576         0.034196            0            1
# 1277    0.052632      0.035088         0.017544            0            1
# 1278    0.070175      0.075472        -0.005296            0            1
# 1279    0.087719      0.094340        -0.006620            0            1
# 1282    0.175439      0.403509        -0.228070            0            1
# 1290    0.684211      0.642857         0.041353            0            1
# 1292    0.736842      0.750000        -0.013158            0            1
# 1293    0.842105      0.125000         0.717105            0            1
# 1294    1.000000      0.830508         0.169492            0            1
# 1301    0.807018      0.929825        -0.122807            0            1
# 1302    0.824561      0.867925        -0.043363            0            1
# 1305    0.912281      0.912281         0.000000            0            1
# 1306    0.947368      0.924528         0.022840            0            1
# 1307    0.982456      0.830189         0.152267            0            1

# %% [markdown]
# ### Being-listed streak

# %%
# count across all t
df['overall_count'] = df.groupby('query').value.transform('count')

# %%
df.count()
# Out:
# query              1361
# value              1361
# keyword            1361
# ranking            1361
# geo                1361
# query_timestamp    1361
# query_date         1361
# day                1361
# month              1361
# year               1361
# t                  1361
# rank_t             1361
# rank_t-1           1120
# rank_change        1120
# rank_pct_t         1361
# rank_pct_t-1       1120
# rank_pct_change    1120
# new_entry_t        1361
# dropout_t+1        1361
# listing_count         0
# overall_count      1361
# dtype: int64

# %%
df.groupby('query').overall_count.min().sort_values(ascending=False).head(10)
# Out:
# query
# sustainable and responsible investment           24
# axis esg equity fund                             23
# sustainable finance disclosure regulation        23
# international platform on sustainable finance    23
# global sustainable investment alliance           23
# sustainable responsible investment               22
# sdgs                                             22
# eu action plan on sustainable finance            22
# expert panel on sustainable finance              22
# global sustainable investment review             21
# Name: overall_count, dtype: int64
